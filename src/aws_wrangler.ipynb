# %%
import awswrangler as wr
import pandas as pd
from datetime import datetime

df = pd.DataFrame({"id": [1, 2], "value": ["foo", "boo"]})


wr.config.to_pandas()

# Storing data on Data Lake
# wr.pd.to_parquet(
#     df=df,
#     path="/home/pydev/workflow/dt_unifed_statistics/src",
#     dataset=True,
#     database="my_db",
#     table="my_table"
# )
# Out:
#                                         name  \
# 0                                 catalog_id
# 1                    concurrent_partitioning
# 2                              ctas_approach
# 3                                   database
# 4                max_cache_query_inspections
# 5                          max_cache_seconds
# 6                   max_remote_cache_entries
# 7                    max_local_cache_entries
# 8            athena_query_wait_polling_delay
# 9        cloudwatch_query_wait_polling_delay
# 10    lakeformation_query_wait_polling_delay
# 11           neptune_load_wait_polling_delay
# 12  timestream_batch_load_wait_polling_delay
# 13     emr_serverless_job_wait_polling_delay
# 14                             s3_block_size
# 15                                 workgroup
# 16                                 chunksize
# 17                         suppress_warnings
# 18                             dtype_backend
# 19                           s3_endpoint_url
# ...
